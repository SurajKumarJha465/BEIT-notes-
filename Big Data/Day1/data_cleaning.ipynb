# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentData.csv")

# %%
df.drop_duplicates(inplace=True)

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Name"] = df["Name"].fillna("Unknown")
df["Score"] = df["Score"].fillna(df["Score"].mean())
df["Gender"] = df["Gender"].replace("NULL", np.nan)
df["Gender"] = df["Gender"].fillna("Unknown")

# %%
df["Gender"] = df["Gender"].replace({
    "M": "Male",
    "F": "Female",
    "male": "Male",
    "female": "Female"
})

# %%
df["Phone"] = df["Phone"].astype(str)

df["Phone"] = df["Phone"].str.replace(r"[^0-9]", "", regex=True)

# %%
df["Address"] = df["Address"].str.replace(r"^[._/]+", "", regex=True)
df["Address"] = df["Address"].str.replace(r"[._]+$", "", regex=True)

# %%
df["Name"] = df["Name"].replace({
    "Supreeme": "Supreme",
    "Prasant": "Prashant"
})

# %%
df["Age"] = df["Age"].astype(int)
df["Score"] = df["Score"].astype(int)

# %%
print(df.isnull().sum())
# Out:
# Student_ID    0
# Name          0
# Age           0
# Gender        0
# Phone         0
# Grade         0
# Score         0
# Address       0
# Hobby         0
# dtype: int64

# %%
df.to_csv("cleaned_student_data.csv", index=False)

print("Data cleaned successfully!")
print(df.head(12))
# Out:
# Data cleaned successfully!
#     Student_ID      Name  Age   Gender        Phone Grade  Score  \
# 0            1      Sita   20   Female   9851164494     A     90
# 1            2     Shyam   22     Male   9851985123     B     80
# 2            3      Hari   21     Male    986221235     C     70
# 4            5      Rita   22   Female   4566564654     B     85
# 5            6       Ram   30  Unknown  46456546546     A     80
# 6            7  Prashant   20     Male    254252452     A     90
# 7            8     Satya   22     Male   4242425555     B     80
# 8            9   Supreme   21     Male    545454454     C     70
# 9           10     Deepa   22   Female    121212121     A     80
# 10          11    Sarita   23   Female  12416212132     A     80
# 11          12   Unknown   25     Male  98565121212     A     80
#
#                   Address       Hobby
# 0               Kathmandu     Singing
# 1                Lalitpur     Dancing
# 2   SukukDhoka, Bhaktapur       Music
# 4                 Pokhara     Cricket
# 5      Ghantaghar, Dharan  Basketball
# 6               Kathmandu    Politics
# 7                Lalitpur      Coding
# 8               Bhaktapur  Basketball
# 9               Kathmandu       Music
# 10      Lakeside, Pokhara       Books
# 11       Bandipur, Tanahu     Cricket
